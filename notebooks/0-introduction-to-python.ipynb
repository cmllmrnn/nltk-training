# %%
import numpy as np

x = np.array([1,2,3])

# %%
a = np.zeros((2,2))

# %%
b = np.ones((2,2))

# %%
a/b
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
c = np.random.randint(10, size=(5))
d = np.random.randint(10, size=(5))
c+d
c-d
c*d
c/d
# Out:
# array([0.71428571, 0.66666667, 0.75      , 4.        , 1.        ])

# %%
print(a==b)
# Out:
# [[False False]
#  [False False]]

# %%
x = np.array([[1,2],[3,4]])

print(np.sum(x))
print(np.sum(x, axis=0)) # sum of each column
print(np.sum(x, axis=1)) # sum of each row
# Out:
# 10
# [4 6]
# [3 7]
